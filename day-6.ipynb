# %%
import pandas as pd

diamond_df = pd.read_csv("/kaggle/input/datasets/lovishbansal123/diamond-dataset/diamonds.csv")
#Series = Column of data, this is one column from excel
#Dataframe = The entire set of data, think about the excel where we have the entire excel 

# diamond_df.head(100)
# diamond_df.tail()
# diamond_df.info()
# diamond_df.describe() # Gets simple stats

diamond_df

# %% [markdown]
# ## Important Series Methods
#
# * `head()`
# * `tail()`
# * `describe()`
# * `unique()`
# * `nunique()`
# * `nlargest()`
# * `nsmallest()`
# * `value_counts()`
# * `plot()` YAY!

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shivamb/netflix-shows")

print("Path to dataset files:", path)

# %%
netflix = pd.read_csv("/kaggle/input/datasets/shivamb/netflix-shows/netflix_titles.csv")

netflix.info()

# %%
houses[houses["view"]== 4]
houses[houses["grade"] >= 11]
houses[(houses["grade"] >= 11) & (houses["view"] == 4)]

# %%
mature = netflix["rating"].isin(["TV-MA", "R", "PG-13"])
netflix[mature]

# %%
countries = ["India", "Japan", "South Korea"]
netflix[netflix["country"].isin(countries)]

# %%
mins.index

# %%
houses.price.max()
